# %% [markdown]
# # Clase 1 de corte 2
# ## Avril Ariza
#
# ## Atributos que necesita un estudiante de la Sabana
#
# ## Datos personales
# ### nombre
# ### apellido
#
#
# ## Datos académicos
# ### codigo_estudiantil
# ### carrera
# ### facultad
# ### semestre
# ### promedio
# ### creditos_aprobados
# ### materias_inscritas (lista)
